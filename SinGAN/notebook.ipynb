# %%
# !pip install torch torchvision matplotlib tqdm

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !rm -rf /content/TrainedModels/
# !python /content/drive/MyDrive/SinGAN-original/main_train.py --input_dir '/content/drive/MyDrive/SinGAN-original/Input/Images/' --input_name 'birds.png' --mode 'train' --not_cuda
